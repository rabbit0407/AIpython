# %%
a=7
b=11
c=a
a=b
b=c

# %%
a
# Out:
# 11

# %%
b
# Out:
# 7

# %%
a=7
b=11

# %%
a,b=b,a

# %%
a
# Out:
# 11

# %%
b
# Out:
# 7

# %%
a=input()
# Out:
# 20

# %%
b=input()
# Out:
# 30

# %%
a
# Out:
# '20'

# %%
b
# Out:
# '30'

# %%
a+b
# Out:
# '2030'

# %%
a-b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_286/3931802818.py in <cell line: 0>()
# ----> 1 a-b
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
int(a)-int(b)
# Out:
# -10

# %%
float(a)-float(b)
# Out:
# -10.0

# %%
int(25.5)+int(25.5)
# Out:
# 50

# %%
a=int(input())
# Out:
# 20

# %%
a
# Out:
# 20

# %%
a=int(input('a값을 입력하시오: '))
# Out:
# a값을 입력하시오: 20

# %%
age=int(input('나이를 입력하시오 '))
name=input('이름을 입력하시오 ')
r=float(input('반지름을 입력하시오 '))
# Out:
# 나이를 입력하시오 20
# 이름을 입력하시오 홍길동
# 반지름을 입력하시오 3.14

# %%
print('a=',a,'b=',b,'c=',c)
# Out:
# a= 20 b= 30 c= 7

# %%
print('a=',a,end='')
print('b=',b,end='')
print('c=',c)
# Out:
# a= 20b= 30c= 7

# %%
print(f'이름은 {name}이고 나이는 {age} 입니다.')
# Out:
# 이름은 홍길동이고 나이는 20 입니다.

# %%
시간=int(input('시간을 입력하시오 '))
시=시간//60
분=시간%60
print(시,"시",분,"분")
# Out:
# 시간을 입력하시오 510
# 8 시 30 분

# %%
m = int(input("분을 입력하세요: "))
h, mm = divmod(m, 60)
print(f"{h:02d}:{mm:02d}")
# Out:
# 분을 입력하세요: 510
# 08:30

# %%
# 사용자에게 정수를 입력받습니다.
num = int(input("숫자를 입력하세요: "))

# 2로 나눈 나머지(%)가 0이면 짝수, 아니면 홀수입니다.
if num > 0:
    print("양수입니다.")
else:
    print("음수입니다.")
# Out:
# 숫자를 입력하세요: 0
# 음수입니다.

# %%
커피 = 2000
라떼 = 3000
녹차 = 2500
주스 = 2800
커피주문수 = int(input('커피는 몇 잔? '))
라떼주문수 = int(input('라떼는 몇 잔? '))
녹차주문수 = int(input('녹차는 몇 잔? '))
주스주문수 = int(input('주스는 몇 잔? '))
주문금액=커피*커피주문수+라떼*라떼주문수+녹차*녹차주문수+주스*주스주문수
print(f"주문금액은 {주문금액}원입니다.")
# Out:
# 커피는 몇 잔? 5
# 라떼는 몇 잔? 4
# 녹차는 몇 잔? 3
# 주스는 몇 잔? 2
# 주문금액은 35100원입니다.
