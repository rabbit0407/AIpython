# %%
i=0
while i < 5 :
  i+=1
  if i ==3 :
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5

# %%
a=[1,2,3]
b=['apple','banana']
c=[1,"hi",3.14,[10,20]]
d=[]

# %%
c
# Out:
# [1, 'hi', 3.14, [10, 20]]

# %%
b
# Out:
# ['apple', 'banana']

# %%
d
# Out:
# []

# %%
a.append(4)

# %%
a
# Out:
# [1, 2, 3, 4]

# %%
a[2]=5

# %%
a
# Out:
# [1, 2, 5, 4]

# %%
len(a)
# Out:
# 4

# %%
sum(a)
# Out:
# 12

# %%
list(reversed(a))
# Out:
# [4, 5, 2, 1]

# %%
a
# Out:
# [1, 2, 5, 4]

# %%
sorted(a)
# Out:
# [1, 2, 4, 5]

# %%
a
# Out:
# [1, 2, 5, 4]

# %%
fruits=["apple", "banana", "cherry"]

# %%
for i in fruits:
  print(i)
# Out:
# apple
# banana
# cherry

# %%
fruits.extend(["orange","mango"])

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'mango']

# %%
len(fruits)
# Out:
# 5

# %%
for i, fruit in enumerate(fruits):
   print(f"{i+1}. {fruit}")
# Out:
# 1. apple
# 2. banana
# 3. cherry
# 4. orange
# 5. mango
# 6. [<built-in method upper of str object at 0x7aae30147cf0>]
# 7. [<built-in method upper of str object at 0x7aae3014c660>]
# 8. [<built-in method upper of str object at 0x7aae3014d230>]
# 9. [<built-in method upper of str object at 0x7aae3a61de90>]
# 10. [<built-in method upper of str object at 0x7aae30147a50>]

# %%
joseon_kings = ["태조", "정종", "태종", "세종", "문종", "단종", "세조", "예종", "성종",
    "연산군", "중종", "인종", "명종", "선조", "광해군", "인조", "효종", "현종",
    "숙종", "경종", "영조", "정조", "순조", "헌종", "철종", "고종", "순종"]

# %%
b=int(input("몇 대 왕이 궁금하신가요? 숫자로 입력해주세요. ^^ "))
print(joseon_kings[b-1])
# Out:
# 몇 대 왕이 궁금하신가요? 숫자로 입력해주세요. ^^ 4
# 세종

# %%
c=input("어떤 왕이 몇 대인지 궁금하신가요? ")
print(f"{c} 왕은 {joseon_kings.index(c)+1}대 입니다.")
# Out:
# 어떤 왕이 몇 대인지 궁금하신가요? 세종
# 세종 왕은 4대 입니다.

# %%
for i in list(reversed(joseon_kings)):
  print(i)
# Out:
# 순종
# 고종
# 철종
# 헌종
# 순조
# 정조
# 영조
# 경종
# 숙종
# 현종
# 효종
# 인조
# 광해군
# 선조
# 명종
# 인종
# 중종
# 연산군
# 성종
# 예종
# 세조
# 단종
# 문종
# 세종
# 태종
# 정종
# 태조
