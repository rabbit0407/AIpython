# %%
a=float(input("첫 번째 수를 입력하세요: "))
b=float(input("두 번째 수를 입력하세요: "))

print(f"덧셈: {a} + {b} = {a+b}")
print(f"뻴셈: {a} - {b} = {a-b}")
print(f"곱셈: {a} * {b} = {a*b}")
print(f"나눗셈: {a} / {b} = {a/b}")
# Out:
# 첫 번째 수를 입력하세요: 5
# 두 번째 수를 입력하세요: 4
# 덧셈: 5.0 + 4.0 = 9.0
# 뻴셈: 5.0 - 4.0 = 1.0
# 곱셈: 5.0 * 4.0 = 20.0
# 나눗셈: 5.0 / 4.0 = 1.25
