# %%
print("can't")
# Out:
# can't

# %%
print('can\'t')
# Out:
# can't

# %%
score1=[1,2,3,4,5]
score2=(1,2,3,4,5)
score3={'A':70,'B':50}

# %%
type(score1)
type(score2)
type(score3)
# Out:
# dict

# %%
score1[0]=10

# %%
score1
# Out:
# [10, 2, 3, 4, 5]

# %%
score3['A']=100

# %%
score3
# Out:
# {'A': 100, 'B': 50}

# %%
cafe_menu = {
    "아메리카노(Ice/Hot)": 4500,
    "카페라떼(Ice/Hot)": 5200,
    "바닐라라떼(Ice/Hot)": 5700,
    "카푸치노(Hot)": 5200,
    "카라멜마키아토(Ice/Hot)": 5900,
    "콜드브루": 5500,
    "카페모카(Ice/Hot)": 6000,
    "초콜릿라떼(Ice/Hot)": 5800,
    "말차라떼(Ice/Hot)": 6200,
    "자몽에이드(Ice)": 6500
}

# %%
countries_capitals = {
    "대한민국": "서울",
    "일본": "도쿄",
    "중국": "베이징",
    "미국": "워싱턴 D.C.",
    "캐나다": "오타와",
    "영국": "런던",
    "프랑스": "파리",
    "독일": "베를린",
    "이탈리아": "로마",
    "스페인": "마드리드",
    "러시아": "모스크바",
    "호주": "캔버라",
    "뉴질랜드": "웰링턴",
    "브라질": "브라질리아",
    "멕시코": "멕시코시티",
    "인도": "뉴델리",
    "태국": "방콕",
    "베트남": "하노이",
    "인도네시아": "자카르타",
    "터키": "앙카라"
}

# %%
for key, value in cafe_menu.items():
  print(f"{key}의 가격은 {value}원입니다.")
# Out:
# 아메리카노(Ice/Hot)의 가격은 4500원입니다.
# 카페라떼(Ice/Hot)의 가격은 5200원입니다.
# 바닐라라떼(Ice/Hot)의 가격은 5700원입니다.
# 카푸치노(Hot)의 가격은 5200원입니다.
# 카라멜마키아토(Ice/Hot)의 가격은 5900원입니다.
# 콜드브루의 가격은 5500원입니다.
# 카페모카(Ice/Hot)의 가격은 6000원입니다.
# 초콜릿라떼(Ice/Hot)의 가격은 5800원입니다.
# 말차라떼(Ice/Hot)의 가격은 6200원입니다.
# 자몽에이드(Ice)의 가격은 6500원입니다.

# %%
총가격=0
for value in cafe_menu.values():
  총가격=총가격+value
print(f'총가격은 {총가격}원입니다.')
# Out:
# 총가격은 56500원입니다.

# %%
print(cafe_menu)
a=input("주문하실 음료를 말씀해주세요.")
d=int(input("주문하실 수량을 입력해주세요."))
for b,c in cafe_menu.items():
  if a==b:
    print(f"주문하신 {b} {d}잔은 {c*d}원 입니다.")
# Out:
# {'아메리카노(Ice/Hot)': 4500, '카페라떼(Ice/Hot)': 5200, '바닐라라떼(Ice/Hot)': 5700, '카푸치노(Hot)': 5200, '카라멜마키아토(Ice/Hot)': 5900, '콜드브루': 5500, '카페모카(Ice/Hot)': 6000, '초콜릿라떼(Ice/Hot)': 5800, '말차라떼(Ice/Hot)': 6200, '자몽에이드(Ice)': 6500}
# 주문하실 음료를 말씀해주세요.콜드브루
# 주문하실 수량을 입력해주세요.5
# 주문하신 콜드브루 5잔은 27500원 입니다.
